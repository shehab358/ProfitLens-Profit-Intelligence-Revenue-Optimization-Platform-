# %%
import pandas as pd

# %%
comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest",
        "XGBoost"
    ],
    "Validation MAE": [
        310.3873,
        316.4012,
        308.9664
    ],
    "Validation RMSE": [
        406.8079,
        414.8779,
        403.0915
    ],
    "Validation R²": [
        0.9891,
        0.9887,
        0.9894
    ],
    "Test MAE": [
        443.4031,
        442.1999,
        446.1986
    ],
    "Test RMSE": [
        714.5258,
        690.7829,
        744.4561
    ],
    "Test R²": [
        0.9787,
        0.9801,
        0.9769
    ]
})

comparison
# Out:
#                Model  Validation MAE  Validation RMSE  Validation R²  \
# 0  Linear Regression        310.3873         406.8079         0.9891
# 1      Random Forest        316.4012         414.8779         0.9887
# 2            XGBoost        308.9664         403.0915         0.9894
#
#    Test MAE  Test RMSE  Test R²
# 0  443.4031   714.5258   0.9787
# 1  442.1999   690.7829   0.9801
# 2  446.1986   744.4561   0.9769
