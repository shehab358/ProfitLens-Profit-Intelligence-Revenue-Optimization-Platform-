# %%
import pandas as pd
import json
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
input_dir = "../../data/processed/feature_selection"

with open(f"{input_dir}/selected_features.json") as f:
    meta = json.load(f)

target = meta["target"]
selected_features = meta["selected_features"]

train_final = pd.read_csv(f"{input_dir}/train_final.csv")
validation_final = pd.read_csv(f"{input_dir}/validation_final.csv")
test_final = pd.read_csv(f"{input_dir}/test_final.csv")

X_train_final = train_final[selected_features]
y_train = train_final[target]

X_validation_final = validation_final[selected_features]
y_validation = validation_final[target]

X_test_final = test_final[selected_features]
y_test = test_final[target]

print("Number of features:", len(selected_features))
print("Train:", X_train_final.shape)
print("Validation:", X_validation_final.shape)
print("Test:", X_test_final.shape)
# Out:
# Number of features: 26
# Train: (16200, 26)
# Validation: (2760, 26)
# Test: (2550, 26)

# %%
lr_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LinearRegression())
])

lr_pipeline.fit(X_train_final, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_lr_pred = lr_pipeline.predict(X_validation_final)

print("MAE:", mean_absolute_error(y_validation, y_lr_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_validation, y_lr_pred)))
print("R²:", r2_score(y_validation, y_lr_pred))
# Out:
# MAE: 124.09499374396839
# RMSE: 165.71714230913275
# R²: 0.9107753261733313

# %%
y_lr_test_pred = lr_pipeline.predict(X_test_final)

mae_lr_test = mean_absolute_error(y_test, y_lr_test_pred)
rmse_lr_test = np.sqrt(mean_squared_error(y_test, y_lr_test_pred))
r2_lr_test = r2_score(y_test, y_lr_test_pred)

print("Linear Regression Test Metrics")
print(f"MAE:  {mae_lr_test:.4f}")
print(f"RMSE: {rmse_lr_test:.4f}")
print(f"R²:   {r2_lr_test:.4f}")
# Out:
# Linear Regression Test Metrics
# MAE:  186.5730
# RMSE: 282.5202
# R²:   0.8407
