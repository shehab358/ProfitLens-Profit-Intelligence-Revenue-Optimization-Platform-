# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
df1 = pd.read_csv(
    "../../data/processed/01_square_item_sales_detail_24mo_preprocessed.csv"
)

df2 = pd.read_csv(
    "../../data/processed/02_ground_truth_event_calendar.csv"
)

# %%
print(df1["Date"].min(), df1["Date"].max())
print(df2["Date"].min(), df2["Date"].max())
# Out:
# 2024-01-01 2025-12-31
# 2024-01-01 2025-12-31

# %%
merged_df = df1.merge(
    df2,
    on="Date",
    how="left",
    validate="many_to_one"
)

# %%
print("Before:", df1.shape)
print("After :", merged_df.shape)
merged_df["Event"].isna().sum()
# Out:
# Before: (970838, 36)
# After : (970838, 45)
# 0

# %%
merged_df.to_csv("../../data/processed/FullDataSet.csv", index=False)
